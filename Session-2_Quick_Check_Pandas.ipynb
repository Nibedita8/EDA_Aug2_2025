# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **step-1: check where is your dataset**

# %%
file_path_visa=r"C:\Users\HP\Documents\Python\NareshIT\Visadataset.csv"
pd.read_csv(file_path_visa)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path_bank=r"C:\Users\HP\Documents\Python\NareshIT\bank.csv"
pd.read_csv(file_path_bank)
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
file_path_visa=r"C:\Users\HP\Documents\Python\NareshIT\bank.csv"
pd.read_csv(file_path_visa,sep=";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
file_path_visa=r"C:\Users\HP\Documents\Python\NareshIT\Visadataset.csv"
visa_df=pd.read_csv(file_path_visa)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - shape
#
# - size
#
# - dtypes
#
# - columns
#
# - drop_duplicates
#
# - isnull
#
# - info

# %%
print(visa_df.shape)
print("number of rows are:",visa_df.shape[0])
print("number of columns are:",visa_df.shape[1])
# Out:
# (25480, 12)
# number of rows are: 25480
# number of columns are: 12

# %%
visa_df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
l=['A','B','C']
l.index('C')
# Out:
# 2

# %%
visa_df.columns.index('case_status')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 visa_df.columns.index('case_status')
#
# AttributeError: 'Index' object has no attribute 'index'

# %%
list(visa_df.columns) # storing columns in al list from dataframe
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa_df.columns.to_list()  # storing columns in al list from dataframe
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa_df.index     # indexes of dataframe
# Out:
# RangeIndex(start=0, stop=25480, step=1)

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()  # sum of all null values, column by column
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.drop_duplicates()  # checking for any duplicate value in any column
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df1=visa_df.copy()  # creating a copy of visa_df

# %%
visa_df1.shape,visa_df.shape
# Out:
# ((25480, 12), (25480, 12))

# %%
visa_df.dtypes  # types of values stored in columns of dataframe(visa_df)
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - series is key-value pair
#
# - series can form a dictionary when we type cast dict
#
# - series can also easily convert in to dataframe

# %%
pd.DataFrame(visa_df.dtypes,columns=['Type']) # here we convert visa_df.dtypes series to a dataframe
# Out:
#                           Type
# case_id                 object
# continent               object
# education_of_employee   object
# has_job_experience      object
# requires_job_training   object
# no_of_employees          int64
# yr_of_estab              int64
# region_of_employment    object
# prevailing_wage        float64
# unit_of_wage            object
# full_time_position      object
# case_status             object

# %% [markdown]
# **TASK-1**
#
# - How to make index as column

# %%
df1=pd.DataFrame(visa_df.dtypes,columns=['Type'])
df1.reset_index(inplace=True)  # all indexes are convert in to a column named index by default after using reset_index
df1
# Out:
#                     index     Type
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
df1=pd.DataFrame(visa_df.dtypes,columns=['Type'])
df1.reset_index(inplace=True)
df1.rename(columns={'index':'Columns'},inplace=True) # changing column names from 'index' to 'Columns'
df1
# Out:
#                   Columns     Type
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
visa_df.dtypes.to_dict() # convering to dictionary from series
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dict(visa_df.dtypes) # convering to dictionary from series
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dict(visa_df.dtypes).keys()
# Out:
# dict_keys(['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status'])

# %%
visa_df.dtypes.to_dict().keys()
# Out:
# dict_keys(['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status'])

# %%
list(visa_df.dtypes.to_dict().keys())
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
list(visa_df.dtypes.to_dict().values())
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O')]

# %% [markdown]
# **Task-2**
#
# - Extract Categorical and Numerical columns in separate list

# %%
types=visa_df.dtypes.to_dict().values()
cols=visa_df.dtypes.to_dict().keys()
for i in types:
    print(i)
# Out:
# object
# object
# object
# object
# object
# int64
# int64
# object
# float64
# object
# object
# object

# %%
cat=[]
num=[]
data_types=visa_df.dtypes.to_dict().items()
for i,j in data_types:
    if j=='object':
        cat.append(i)
    else:
        num.append(i)

print("Categorical Datas are:",cat)
print("==============================================================================")
print("Numerical Datas are:",num)
# Out:
# Categorical Datas are: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ...
# Numerical Datas are: ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
data_types=visa_df.dtypes.to_dict().items()
cat=[i for i,j in data_types if j=='object']
num=[i for i,j in data_types if j!='object']

print("Categorical Datas are:",cat)
print("==============================================================================")
print("Numerical Datas are:",num)
# Out:
# Categorical Datas are: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ...
# Numerical Datas are: ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **select-dtypes**

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **My Logic**

# %%
types=visa_df.dtypes.to_dict().values()
cols=visa_df.dtypes.to_dict().keys()
for i,j in zip(types,cols):
    if i=='object':
        print(j)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# region_of_employment
# unit_of_wage
# full_time_position
# case_status

# %%
types=visa_df.dtypes.to_dict().values()
cols=visa_df.dtypes.to_dict().keys()
for i,j in zip(types,cols):
    if i=='int64':
        print(j)
# Out:
# no_of_employees
# yr_of_estab

# %%
types=visa_df.dtypes.to_dict().values()
cols=visa_df.dtypes.to_dict().keys()
for i,j in zip(types,cols):
    if i=='float64':
        print(j)
# Out:
# prevailing_wage
