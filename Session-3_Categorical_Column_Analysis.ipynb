# %% [markdown]
# **Step-1: Important the packages**

# %%
import pandas as pd  # Dataframes operations
import numpy as np # math operations
import matplotlib.pyplot as plt # plotting
import seaborn as sns # plotting

# %% [markdown]
# **Step-2: Read visa datasets**

# %%
file_path=r"C:\Users\HP\Documents\Python\NareshIT\Visadataset.csv"
visa_df=pd.read_csv(file_path) # converting csv file to a data frame

# %% [markdown]
# **Step-3: Divided in to Categorical and Numerical Columns**

# %%
types=visa_df.dtypes.to_dict() # converting dataframe to a dictionary
cat=[i for i,j in types.items() if j=='object'] # converting dictionary in to a list using list comprehension
num=[i for i,j in types.items() if j!='object'] # converting dictionary in to a list using list comprehension

# %%
len(cat),len(num)
# Out:
# (9, 3)

# %%
cat=visa_df.select_dtypes(include='object').columns  # storing only object sseries columns in a series
num=visa_df.select_dtypes(exclude='object').columns  # storing other series column in a series

# %%
import pandas as pd  # Dataframes operations
import numpy as np # math operations
import matplotlib.pyplot as plt # plotting
import seaborn as sns # plotting

file_path=r"C:\Users\HP\Documents\Python\NareshIT\Visadataset.csv"
visa_df=pd.read_csv(file_path) # converting csv file to a data frame

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **step-4: How to read a Column**

# %%
visa_df['continent']
visa_df[['continent']]
cols=['continent','case_status']
visa_df[cols]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %%
visa_df['continent'] # a series of objects will come with index numbers from specified column
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']] # a dataframe will come with index and column name
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
cols=['continent','case_status']
visa_df[cols] # two column will come with index numbers in a data frame
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %%
visa_df['continent']
visa_df[['continent']]
visa_df.loc[:,'continent']
visa_df.loc[:,['continent']]
list(visa_df.select_dtypes(include="object").columns).index('continent')  # convert series to list then access the index number and store
Id=cat.to_list().index('continent') # convert series to list then access the index number and store
Id
visa_df.iloc[:,Id]
visa_df.iloc[:,[Id]]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.loc[:,'continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
Id=cat.to_list().index('continent') # convert series to list then access the index number and store
visa_df.iloc[:,Id]
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[Id]]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **continent column analysis**

# %%
visa_df[['continent']]  # dataFrame
visa_df['continent']  # series
visa_df['continent'].values # values 25480
# .values returns the underlying NumPy array.
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
visa_df[['continent']] # data frame
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df['continent']  # series
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].values # values 25480
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
 len(visa_df['continent'].values)
# Out:
# 25480

# %%
dir(pd.DataFrame)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %% [markdown]
# **Unique**

# %%
visa_df['continent'].unique() # arrays of unique values peresent in the continent column
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].nunique() # number of unique values present in the continent
# Out:
# 6

# %% [markdown]
# **TASK:**
# - we want to know how many asia applicants are from total data 25480

# %%
visa_df # Dataframe
visa_df['continent'] # return a series of value of that perticular Column
con=visa_df['continent']=='Asia' # it will check is there any value named 'Asia' in continent column
len(visa_df[con]) # calculate how many Asia values are present in dataframe
# Out:
# 16861

# %%
# for value 'Africa' it will check whether there any data named africa
con=visa_df['continent']=='Africa'
len(visa_df[con])
# Out:
# 551

# %%
# for North America
con=visa_df['continent']=='North America'
len(visa_df[con])
# Out:
# 3292

# %%
# for Europe
con=visa_df['continent']=='Europe'
len(visa_df[con])
# Out:
# 3732

# %%
con=visa_df['continent']=='Asia'
con=visa_df['continent']=='Asia'
con=visa_df['continent']=='Asia'
con=visa_df['continent']=='Asia'
con=visa_df['continent']=='Asia'
con=visa_df['continent']=='Asia'


# take a empty list
# Apply for loop
# con=visa_df['continent']==i
# len(visa_df[con])

# %%
labels=visa_df['continent'].unique() # storing unique values of continent coluns in a variable
for i in labels:
    print(i)
# Out:
# Asia
# Africa
# North America
# Europe
# South America
# Oceania

# %%
# storing how many unique values are present in that column 
l=[]
for i in labels:
    # print(i)
    con=visa_df['continent']==i
    count=len(visa_df[con])
    l.append(count) # storing number of applicants in a list

# %%
l
# Out:
# [16861, 551, 3292, 3732, 852, 192]

# %%
labels
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
continent_df=pd.DataFrame(zip(labels,l),columns=['Continents','Number of Applicants'])
continent_df
# Out:
#       Continents  Number of Applicants
# 0           Asia                 16861
# 1         Africa                   551
# 2  North America                  3292
# 3         Europe                  3732
# 4  South America                   852
# 5        Oceania                   192

# %%
# my logic to create dataframe
cdf=pd.DataFrame()
cdf['Countinents']=labels # here in labels there is the unique values are present
cdf['Numbers of Applicants']=l  # here in l how many numbers of differnt unique values are present that stored
cdf
# Out:
#      Countinents  Numbers of Applicants
# 0           Asia                  16861
# 1         Africa                    551
# 2  North America                   3292
# 3         Europe                   3732
# 4  South America                    852
# 5        Oceania                    192

# %%
cdf.to_csv('Continent_data',index=False) # converting data frame to a csv file

# %% [markdown]
# **Value Counts**

# %%
visa_df['continent'].value_counts() # doing the same operation using value count method()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
visa_df['continent'].value_counts().values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
visa_df['continent'].value_counts()
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
pd.DataFrame(zip(keys,values),columns=['Continents','Number of Applicants'])
# Out:
#       Continents  Number of Applicants
# 0           Asia                 16861
# 1         Europe                  3732
# 2  North America                  3292
# 3  South America                   852
# 4         Africa                   551
# 5        Oceania                   192

# %% [markdown]
# **Dont Work on CASE ID:25480**

# %% [markdown]
# **Bar Chart**

# %%
plt.figure(figsize=(10,5))  # figure is always in top
plt.bar(keys,values) # here overlap occurs in x axis
plt.xlabel('Continents')
plt.ylabel('Number of Applicants')
plt.title('Continent Bar Chart')
plt.savefig('continent_bar_chart.jpg')
plt.show()

# %%
plt.figure(figsize=(10,5))  # figure is always in top
colors=['purple','red','yellow','green','gray','blue']
plt.bar(keys,values,color=colors) # here overlap occurs in x axis
plt.xlabel('Continents')
plt.ylabel('Number of Applicants')
plt.title('Continent Bar Chart')
plt.savefig('continent_bar_chart.jpg')
plt.show()

# %%
plt.figure(figsize=(10,5))  # figure is always in top
colors=['purple','red','yellow','green','gray','blue']
charts=plt.bar(keys,values,color=colors) # here overlap occurs in x axis
plt.xlabel('Continents')
plt.ylabel('Number of Applicants')
plt.title('Continent Bar Chart')
plt.bar_label(charts)
plt.savefig('continent_bar_chart.jpg')
plt.show()

# %%
plt.figure(figsize=(10,5))  # figure is always in top
colors=['purple','red','yellow','green','gray','blue']
charts=plt.bar(keys,values,color=colors) # here overlap occurs in x axis
plt.xlabel('Continents')
plt.ylabel('Number of Applicants')
plt.title('Continent Bar Chart')

for i in charts:
    height = i.get_height()
    plt.text(i.get_x() + i.get_width()/2.0, height, f'{height}', ha='center', va='bottom')


plt.savefig('continent_bar_chart.jpg')
plt.show()

# %%
plt.figure(figsize=(10,5))  # figure is always in top
colors=['purple','red','yellow','green','gray','blue']
charts=plt.bar(keys,values,color=colors) # here overlap occurs in x axis
plt.xlabel('Continents')
plt.ylabel('Number of Applicants')
plt.title('Continent Bar Chart')

for i in charts:
    height = i.get_height()
    xc=i.get_x() 
    wd=i.get_width()
    h='center'
    v='bottom'
    plt.text(xc+wd/2.0, height, f'{height}',ha=h,va=v)


plt.savefig('continent_bar_chart.jpg')
plt.show()

# %% [markdown]
# # practice

# %% [markdown]
# **for other columns**

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
Id=list(visa_df.columns).index('education_of_employee')
Id
# Out:
# 2

# %%
visa_df['education_of_employee']
visa_df.iloc[:,Id]
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df[['education_of_employee']]
visa_df.iloc[:,[Id]]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %% [markdown]
# **education_of_employee column analysis**

# %%
visa_df['education_of_employee'] # series
visa_df[['education_of_employee']] # dataframes
visa_df['education_of_employee'].values # values in arrays
# Out:
# array(['High School', "Master's", "Bachelor's", ..., "Master's",
#        "Master's", "Bachelor's"], dtype=object)

# %%
len(visa_df['education_of_employee'].values)
# Out:
# 25480

# %% [markdown]
# **unique keys**

# %%
labels=visa_df.iloc[:,2].unique()
labels=visa_df['education_of_employee'].unique()
labels
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
visa_df['education_of_employee'].nunique()
# Out:
# 4

# %% [markdown]
# **Task**
#
# - we want to how many Highscool employees are from total 25480

# %%
labels=visa_df['education_of_employee'].unique()
for i in labels:
    print(i)
# Out:
# High School
# Master's
# Bachelor's
# Doctorate

# %%
l=[]
for i in labels:
    con=visa_df['education_of_employee']==i
    count=len(visa_df[con])
    l.append(count)

print("number of education employees are",l)
# Out:
# number of education employees are [3420, 9634, 10234, 2192]

# %%
education_employee_df=pd.DataFrame(zip(labels,l),columns=['education_employee','numbers_of_education_employee'])
education_employee_df
# Out:
#   education_employee  numbers_of_education_employee
# 0        High School                           3420
# 1           Master's                           9634
# 2         Bachelor's                          10234
# 3          Doctorate                           2192

# %%
education_employee_df.to_csv('Education_Employees_data',index=False)

# %% [markdown]
# **Value counts**

# %%
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
keys=visa_df['education_of_employee'].value_counts().keys()
keys
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
values=visa_df['education_of_employee'].value_counts().values
values
# Out:
# array([10234,  9634,  3420,  2192], dtype=int64)

# %%
pd.DataFrame(zip(keys,values),columns=['education_employee','numbers_of_employee'])
# Out:
#   education_employee  numbers_of_employee
# 0         Bachelor's                10234
# 1           Master's                 9634
# 2        High School                 3420
# 3          Doctorate                 2192

# %% [markdown]
# **Bar-chart**

# %%
colors=['green','red','purple','orange']
bar=plt.bar(keys,values,color=colors)
plt.xlabel('Education_Employees')
plt.ylabel('Numbers_of_Education_Employees')
plt.title('Education_Employee_Bar_Chart')
plt.bar_label(bar)
plt.savefig('education_employee_bar_chart')
plt.show()

# %% [markdown]
# # Session-3(part-ii)
# # 27th June 2025

# %% [markdown]
# - we completed frequency table
#
# - we completed bar chart
#
# - if i want to draw multiple plots we can use a concept subplot

# %% [markdown]
# **subplot**

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %% [markdown]
# **subplots()**

# %%
plt.subplots(1,2)
plt.subplots(2,1)
plt.subplots(2,2)
plt.subplots(1,3)
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
keys=visa_df['continent'].value_counts().keys()
valuess=visa_df['continent'].value_counts().values

# %%
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,5))
    plt.bar(keys,values)

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,i)

# %%
for i in range(1,9):
    plt.subplot(3,3,i)

# %%
plt.figure(figsize=(30,15))
for i in range(1,9):
    keys=visa_df[cat[i]].value_counts().keys()
    values=visa_df[cat[i]].value_counts().values
    plt.subplot(3,3,i)
    plt.bar(keys,values)

# %%
plt.figure(figsize=(30,15))
for i in range(1,len(cat[:])):
    keys=visa_df[cat[i]].value_counts().keys()
    values=visa_df[cat[i]].value_counts().values
    plt.subplot(3,3,i)
    plt.bar(keys,values)

# %%
plt.figure(figsize=(28,14))
for i in range(1,9):
    keys=visa_df[cat[i]].value_counts().keys()
    values=visa_df[cat[i]].value_counts().values
    plt.subplot(3,3,i)
    bars=plt.bar(keys,values)
    plt.bar_label(bars)

# %%
plt.figure(figsize=(30,15))
for i in range(1,9):
    keys=visa_df[cat[i]].value_counts().keys()
    values=visa_df[cat[i]].value_counts().values
    plt.subplot(3,3,i).bar(keys,values)
    plt.bar_label(plt.bar(keys,values))

# %% [markdown]
# **pie chart**

# %%
visa_df['continent'].value_counts(normalize=True)
# Out:
# continent
# Asia             0.661735
# Europe           0.146468
# North America    0.129199
# South America    0.033438
# Africa           0.021625
# Oceania          0.007535
# Name: proportion, dtype: float64

# %%
keys=visa_df['continent'].value_counts(normalize=True).keys()
values=visa_df['continent'].value_counts(normalize=True).values

# %%
df=pd.DataFrame(zip(keys,values),columns=['class_name','Class_frequency_interval'])
df
# Out:
#       class_name  Class_frequency_interval
# 0           Asia                  0.661735
# 1         Europe                  0.146468
# 2  North America                  0.129199
# 3  South America                  0.033438
# 4         Africa                  0.021625
# 5        Oceania                  0.007535

# %%
plt.pie(values)
# Out:
# ([<matplotlib.patches.Wedge at 0x192a7747530>,
# ...
#  [Text(-0.5351743362316361, 0.9610350825224997, ''),
#   Text(-0.10373513115748138, -1.0950977228374372, ''),
#   Text(0.7670026411947619, -0.7884839557024984, ''),
#   Text(1.0546117976794491, -0.3127202522947962, ''),
#   Text(1.0926986108246142, -0.12652962460213996, ''),
#   Text(1.0996917916121562, -0.026037731484255974, '')])

# %%
plt.pie(values)
plt.show()

# %%
plt.pie(values,labels=keys)
plt.show()

# %%
plt.pie(values,
        labels=keys,
       autopct="%0.2f%%")
plt.show()

# %%
plt.pie(values,
        labels=keys,
       autopct="%0.2f%%",
       startangle=180)
plt.show()

# %%
plt.pie(values,
        labels=keys,
       autopct="%0.2f%%",
        shadow=False,
       startangle=180)
plt.show()

# %%
plt.pie(values,
        labels=keys,
        explode=[0.02 for i in range(6)], # here 6 means 6 pieces of keys are available to draw piechart
        autopct="%0.2f%%",
        shadow=False,
        startangle=180)
plt.show()

# %%
plt.pie(values,
        labels=keys,
        explode=[0.02 for i in range(len(keys))],
        autopct="%0.2f%%",
        shadow=False,
        startangle=180,
       radius=2)
plt.show()

# %%
for i in range(1,len(cat[:])):
    keys=visa_df[cat[i]].value_counts(normalize=True).keys()
    values=visa_df[cat[i]].value_counts(normalize=True).values
    plt.figure(figsize=(15,8))
    plt.pie(values,
           labels=keys,
           explode=[0.03 for i in range(len(keys))],
           autopct="%0.02f%%",
           shadow=False,
           startangle=90)
    plt.show()

# %%
for i in range(1,len(cat[:])):
    plt.figure(figsize=(50,35))
    keys=visa_df[cat[i]].value_counts(normalize=True).keys()
    values=visa_df[cat[i]].value_counts(normalize=True).values
    plt.subplot(3,3,i).pie(values,
           labels=keys,
           explode=[0.03 for i in range(len(keys))],
           autopct="%0.02f%%",
           shadow=False,
           startangle=90)

# %%
plt.figure(figsize=(50,35))
for i in range(1,9):
    keys=visa_df[cat[i]].value_counts(normalize=True).keys()
    values=visa_df[cat[i]].value_counts(normalize=True).values
    plt.subplot(3,3,i).pie(values,
                          labels=keys,
                          autopct="%0.2f%%",
                          explode=[0.03 for i in range(len(keys))],
                            startangle=90,
                          radius=1)

# %%
plt.figure(figsize=(50,35))
for i in range(1,len(cat[:])):
    keys=visa_df[cat[i]].value_counts(normalize=True).keys()
    values=visa_df[cat[i]].value_counts(normalize=True).values
    plt.subplot(3,3,i).pie(values,
                          labels=keys,
                          autopct="%0.2f%%",
                          explode=[0.03 for i in range(len(keys))],
                            startangle=90,
                          radius=1)
